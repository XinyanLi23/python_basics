# %%
import os
os.listdir()
#get a list of files and folders
# Out:
# ['.DS_Store',
#  'Python with files.ipynb',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'data.txt']

# %%
import pandas

# %% [markdown]
# ## loading data

# %%
df1 = pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pandas.read_excel("supermarkets.xlsx", sheet_name = 0)
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4 = pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt", sep=";")
df5
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
#pandas.read_csv?    ask for help

# %% [markdown]
# ## set table header row

# %%
df8 = pandas.read_csv("data.txt", header = None)      #header = None will help to move down the first rwo and replace it with a default num
df8
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %% [markdown]
# ## set column names

# %%
df8.columns = ["ID", "Address", "City", "Zip", "Countrt", "Name", "Employees"]
df8
# Out:
#    ID          Address           City               Zip Countrt         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# ## set index column

# %%
df8.set_index("ID")     #set index produces a new data frame rather than modify the existing one
# Out:
#             Address           City               Zip Countrt         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df8
# Out:
#    ID          Address           City               Zip Countrt         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df9 = df8.set_index("ID")  
df9
# Out:
#             Address           City               Zip Countrt         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
#another way
df8.set_index("ID", inplace = True)

# %%
df8
# Out:
#             Address           City               Zip Countrt         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df8.set_index("Address", inplace = True)    #set_index will set a new column as the index and delete the old one
df8
# Out:
#                           City               Zip Countrt         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df8.set_index("Name", inplace = True, drop = False)
df8
# Out:
#                       City               Zip Countrt         Name  Employees
# Name
#  Madeira     San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %%
df8.set_index("Name", inplace = True, drop = False)     #drop = False tells the python that do not drop the column that I am setting as the new index
df8
# Out:
#                       City               Zip Countrt         Name  Employees
# Name
#  Madeira     San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %% [markdown]
# ## Filtering data from a pandas df

# %%
df7 = pandas.read_json("supermarkets.json")
df7
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7 = df7.set_index("Address")

# %%
df7.loc["735 Dolores St":"332 Hill St","Country":"Name"]     #.loc[index label, column name]
# Out:
#                Country         Name
# Address
# 735 Dolores St     USA  Bready Shop
# 332 Hill St        USA  Super River

# %%
df7.loc["332 Hill St","Country"]    #single frame
# Out:
# 'USA'

# %%
df7.loc[:,"Country"]
# Out:
# Address
# 3666 21st St       USA
# 735 Dolores St     USA
# 332 Hill St        USA
# 3995 23rd St       USA
# 1056 Sanchez St    USA
# 551 Alvarado St    USA
# Name: Country, dtype: object

# %%
list(df7.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df7.iloc

# %% [markdown]
# ## .iloc - more common way

# %%
#access the database on indexing not based on labels

# %%
df7.iloc[1:4,1:4]
# Out:
#                          City             State Country
# Address
# 735 Dolores St  San Francisco          CA 94119     USA
# 332 Hill St     San Francisco  California 94114     USA
# 3995 23rd St    San Francisco          CA 94114     USA

# %%
df7.iloc[:,1:4]
# Out:
#                           City             State Country
# Address
# 3666 21st St     San Francisco          CA 94114     USA
# 735 Dolores St   San Francisco          CA 94119     USA
# 332 Hill St      San Francisco  California 94114     USA
# 3995 23rd St     San Francisco          CA 94114     USA
# 1056 Sanchez St  San Francisco        California     USA
# 551 Alvarado St  San Francisco          CA 94114     USA

# %%
df7.iloc[3,1:4]
# Out:
# City       San Francisco
# State           CA 94114
# Country              USA
# Name: 3995 23rd St, dtype: object

# %% [markdown]
# ## Deleting columns and rows

# %%
df7.drop("City",1)
# Out:
# /Users/tutu/Desktop/python_basics/env/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#                  ID             State Country         Name  Employees
# Address
# 3666 21st St      1          CA 94114     USA      Madeira          8
# 735 Dolores St    2          CA 94119     USA  Bready Shop         15
# 332 Hill St       3  California 94114     USA  Super River         25
# 3995 23rd St      4          CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5        California     USA      Sanchez         12
# 551 Alvarado St   6          CA 94114     USA   Richvalley         20

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df7.drop("332 Hill St",0)
# Out:
# /Users/tutu/Desktop/python_basics/env/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#                  ID           City       State Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df7.drop(df7.index[0:3],0)
# Out:
# /Users/tutu/Desktop/python_basics/env/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#                  ID           City       State Country        Name  Employees
# Address
# 3995 23rd St      4  San Francisco    CA 94114     USA  Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA     Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA  Richvalley         20

# %%
df7.drop(df7.columns[0:3],1)
# Out:
# /Users/tutu/Desktop/python_basics/env/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
#                 Country         Name  Employees
# Address
# 3666 21st St        USA      Madeira          8
# 735 Dolores St      USA  Bready Shop         15
# 332 Hill St         USA  Super River         25
# 3995 23rd St        USA   Ben's Shop         10
# 1056 Sanchez St     USA      Sanchez         12
# 551 Alvarado St     USA   Richvalley         20

# %%
df7.index
# Out:
# Index(['3666 21st St', '735 Dolores St', '332 Hill St', '3995 23rd St',
#        '1056 Sanchez St', '551 Alvarado St'],
#       dtype='object', name='Address')

# %%
df7.columns
# Out:
# Index(['ID', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %% [markdown]
# ## add columns & rows

# %%
len(df7.index)
# Out:
# 6

# %%
df7["Continent"] = df7.shape[0]*["North America"]     # add column need to know the len first and multiply  #this is an inplace opertaion

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees      Continent
# Address
# 3666 21st St             8  North America
# 735 Dolores St          15  North America
# 332 Hill St             25  North America
# 3995 23rd St            10  North America
# 1056 Sanchez St         12  North America
# 551 Alvarado St         20  North America

# %%
df7.shape[0]
# Out:
# 6

# %%
df7.shape[0]*["North America"]
# Out:
# ['North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America',
#  'North America']

# %%
df7["Continent"] = df7["Country"]+","+"North America"    #modifying column
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees          Continent
# Address
# 3666 21st St             8  USA,North America
# 735 Dolores St          15  USA,North America
# 332 Hill St             25  USA,North America
# 3995 23rd St            10  USA,North America
# 1056 Sanchez St         12  USA,North America
# 551 Alvarado St         20  USA,North America

# %%
df7_t = df7.T   # add row      # t tranpose the df with exchange the row and column
df7_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# ID                         1                  2                  3
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# ID                         4                  5                  6
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# Country                  USA                USA                USA
# Name              Ben's Shop            Sanchez         Richvalley
# ...

# %%
df7_t["My Address"] = ["My City", "My Country", 10, 7, "My Shop", "My State", "My Continent"]
df7_t
# Out:
# Address         3666 21st St     735 Dolores St        332 Hill St  \
# ID                         1                  2                  3
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St  \
# ID                         4                  5                  6
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# Country                  USA                USA                USA
# Name              Ben's Shop            Sanchez         Richvalley
# ...

# %%
df7 = df7_t.T
df7
# Out:
#                       ID           City             State Country  \
# Address
# 3666 21st St           1  San Francisco          CA 94114     USA
# 735 Dolores St         2  San Francisco          CA 94119     USA
# 332 Hill St            3  San Francisco  California 94114     USA
# 3995 23rd St           4  San Francisco          CA 94114     USA
# 1056 Sanchez St        5  San Francisco        California     USA
# 551 Alvarado St        6  San Francisco          CA 94114     USA
# My Address       My City     My Country                10       7
#
#                         Name Employees          Continent
# Address
# 3666 21st St         Madeira         8  USA,North America
# 735 Dolores St   Bready Shop        15  USA,North America
# 332 Hill St      Super River        25  USA,North America
# 3995 23rd St      Ben's Shop        10  USA,North America
# 1056 Sanchez St      Sanchez        12  USA,North America
# 551 Alvarado St   Richvalley        20  USA,North America
# ...

# %% [markdown]
# ## Ex. Convert address to location (latitude and longitude)

# %%
# convert addresses to coordinates is geocoding
# convert latitudinal and longitude to addresses is reverse geocoding

# %%
df7
# Out:
#                       ID           City             State Country  \
# Address
# 3666 21st St           1  San Francisco          CA 94114     USA
# 735 Dolores St         2  San Francisco          CA 94119     USA
# 332 Hill St            3  San Francisco  California 94114     USA
# 3995 23rd St           4  San Francisco          CA 94114     USA
# 1056 Sanchez St        5  San Francisco        California     USA
# 551 Alvarado St        6  San Francisco          CA 94114     USA
# My Address       My City     My Country                10       7
#
#                         Name Employees          Continent
# Address
# 3666 21st St         Madeira         8  USA,North America
# 735 Dolores St   Bready Shop        15  USA,North America
# 332 Hill St      Super River        25  USA,North America
# 3995 23rd St      Ben's Shop        10  USA,North America
# 1056 Sanchez St      Sanchez        12  USA,North America
# 551 Alvarado St   Richvalley        20  USA,North America
# ...

# %%
import geopy

# %%
dir(geopy)
# Out:
# ['AlgoliaPlaces',
#  'ArcGIS',
#  'AzureMaps',
#  'BANFrance',
#  'Baidu',
#  'BaiduV3',
#  'Bing',
#  'DataBC',
#  'GeoNames',
#  'GeocodeEarth',
#  'Geocodio',
#  'Geolake',
#  'GoogleV3',
#  'Here',
#  'HereV7',
#  'IGNFrance',
#  'LiveAddress',
#  'Location',
#  'MapBox',
#  'MapQuest',
#  'MapTiler',
#  'Nominatim',
#  'OpenCage',
#  'OpenMapQuest',
#  'Pelias',
#  'Photon',
#  'PickPoint',
#  'Point',
#  'Timezone',
#  'TomTom',
#  'What3Words',
#  'What3WordsV3',
#  'Yandex',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  'adapters',
#  'compat',
#  'exc',
#  'format',
#  'geocoders',
#  'get_geocoder_for_service',
#  'get_version',
#  'location',
#  'point',
#  'timezone',
#  'units',
#  'util']

# %%
import ssl
import certifi
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS(scheme='https')

# %%
address = nom.geocode("3395 23rd St, San Francisco, CA 94114")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ...

# %%
address.latitude
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4x/kbkytv1x4jzdxbqblkpfwmgm0000gn/T/ipykernel_16993/3338682982.py in <module>
# ----> 1 address.latitude
#
# NameError: name 'address' is not defined

# %%
n = nom.geocode("735 Dolores St, San Francisco, CA 94114")        # sometimes it's None
print(n)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ...

# %%
address.latitude

# %%
address.longitude

# %%
type(n)

# %% [markdown]
# ## Ex. Convert entire column of df into latitude and longitude

# %%
import pandas
df = pandas.read_csv("supermarkets.csv")
df

# %%
df["Address"] = df["Address"]+","+df["City"]+","+df["State"]+","+df["Country"]
df

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)
df

# %%
df.Coordinates[0]

# %%
df.Coordinates[0].latitude

# %%
df

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df["Longitude"] = df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df
